# %%
#Extract frames from video,  modify some frames and save as video Frames

import cv2
import matplotlib.pyplot as plt

# Opens the Video file
cap= cv2.VideoCapture('/content/bus_cif.y4m')  # very long video. Takes 1 min to execute

#cap= cv2.VideoCapture('globe.mp4')


i=0
while(cap.isOpened()):
    ret, frame = cap.read()
    if ret == False:
         break
# saving each frame as jpg image.Name of the frame starts with 'kang'. Frame number is appended to the name of frame
    cv2.imwrite('abc'+str(i)+'.jpg',frame)
    i+=1

# At the end of loop, i is 900. therefore number of frames in video is last value of i
numb_frames=i

# modify some frames of video
strt_fr=int(numb_frames/3)
stp_fr=int(numb_frames*2/3)

#add white square in the frames to be modified
# use first frame to get the size of frames
img = cv2.imread('abc0.jpg',0)
sh=img.shape

# start and stop row and col numbers to include white square
strt_rw=int(sh[0]*3/10)
stp_rw=int(sh[0]*6/10)
strt_col=int(sh[1]*8/10)
stp_col=int(sh[1]*9/10)

# add white square to the chosen frames

for j in range(strt_fr,stp_fr):
    img = cv2.imread('abc'+str(j)+'.jpg',0)
    img[strt_rw:stp_rw,strt_col:stp_col]=255

    # replace original frame with the modified image/frame
    cv2.imwrite('abc'+str(j)+'.jpg',img)


cap.release()
cv2.destroyAllWindows()

# %%
size=(img.shape[1],img.shape[0])
size
# Out:
# (352, 288)

# %%
plt.imshow(img,cmap='gray')

# %%
#Create Video from Images

import cv2
import numpy as np
import glob

img_array = []
for filename in glob.glob('abc*.jpg'):
    img = cv2.imread(filename)
    #height, width, layers = img.shape
    #size = (width,height)
    img_array.append(img)

# filename: Input video file, fourcc: 4-character code of codec used to compress the frames
#fps: framerate of videostream, framesize: Height and width of frame=5 or 10

out = cv2.VideoWriter('test.avi',cv2.VideoWriter_fourcc(*'DIVX'), 10, size)

for i in range(len(img_array)):
    out.write(img_array[i])


out.release()

# if working in google colab, a new video is created.
#Three dots next to this video has option for down load it.
#The click on downloaded video to run it.

# %%
plt.imshow(img_array[1])
